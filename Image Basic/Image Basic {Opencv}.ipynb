# %%
import numpy as np 
import matplotlib.pyplot as plt
import cv2

# %%
# matplotlib : RGB
# opencv  : BRG

# %%
img = cv2.imread("DATA/00-puppy.jpg")
type(img) # Not need to convert 
img.shape
# Out:
# (1300, 1950, 3)

# %%
plt.imshow(img)

# %%
fiximg=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)  # Converted into orignal img
plt.imshow(fiximg)

# %%
img = cv2.imread('DATA/00-puppy.jpg',cv2.IMREAD_GRAYSCALE)
plt.imshow(img,cmap="gray")
img.max()
# Out:
# 209

# %%
plt.imshow(fiximg)
new=cv2.resize(fiximg,(1300,500))
plt.imshow(new)

# %%
w_ratio = 0.6
h_ratio = 0.6

new1 = cv2.resize(fiximg,(0,0),fiximg,w_ratio,h_ratio)
plt.imshow(new1)

# %%
new1.shape
# Out:
# (780, 1170, 3)

# %%
new1 = cv2.flip(new1,-1)
plt.imshow(new1)

# %%
cv2.imwrite("new1.jpg",new1) # Save image in new format
# Out:
# True

# %%
plt.figure(figsize=(29,44))
plt.imshow(cv2.flip(new1,-1))

# %%
import cv2 
img = cv2.imread("DATA/00-puppy.jpg")
cv2.imshow('pupy',img)
cv2.waitKey()
cv2.DestroyAllWindows()

# %%
import cv2 
import matplotlib.pyplot as plt 
import numpy as np

# %%
img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(img)
type(img)
# Out:
# numpy.ndarray

# %%
# Making shape on that image
img1=cv2.rectangle(img,pt1=(377,1),pt2=(590,150),color=(0,255,0),thickness=6)

# %%
plt.imshow(img1)

# %%
plt.imshow(cv2.rectangle(img,pt1=(200,200),pt2=(400,400),color=(255,0,200),thickness=6))

# %%
# For circle 
img1=cv2.circle(img,center=(100,100),radius=50,color=(255,0,0),thickness=4)
plt.imshow(img1)

# %%
# For circle 
img1=cv2.circle(img1,center=(400,400),radius=50,color=(255,0,0),thickness=-1)
plt.imshow(img1)

# %%
line=cv2.line(img,pt1=(0,0),pt2=(512,512),color=(102,22,33),thickness=6)

# %%
plt.imshow(line)

# %%
font=cv2.FONT_HERSHEY_COMPLEX # Defining font type
plt.imshow(cv2.putText(img1,text="Hello",org=(10,500),color=(255,244,244),thickness=4,fontFace=font,fontScale=5))

# %%
img2 = np.zeros(shape=(513,513,3),dtype=np.int32)

# %%
# New shape 
vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts=vertices.reshape(-1,1,2)
pts  # ONE more dimension
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
poly=cv2.polylines(img2,[pts],isClosed=True,color=(255,0,0),thickness=5)

# %%
plt.imshow(poly)

# %%
 # Call Back -- And Make Shape Circle
# Function 
import cv2
import numpy as np

def draw_circle(event,x,y,flags,param):
    if event == cv2.EVENT_RBUTTONDOWN:
        cv2.circle(img,(x,y),100,(255,255,0),-1)
    elif event == cv2.EVENT_LBUTTONDOWN:
        cv2.circle(img,(x,y),100,(0,255,255),-1)
        
    

## Showing Image With Opencv

img = np.zeros((512,512,3), np.uint8)
cv2.namedWindow(winname="my_drawing")
cv2.setMouseCallback("my_drawing",draw_circle)


while True:
    cv2.imshow("my_drawing",img)
    if cv2.waitKey(20) & 0xFF == 27:
        break
cv2.destroyAllWindows()

# %%
# Make a rectangle
import numpy as np 
import cv2


# variable 

# True when mouse down,false when up
drawing = False 
ix,iy = -1,-1


# function
def draw_rectangle(event,x,y,flags,param):
    global ix,iy,drawing
    if event == cv2.EVENT_LBUTTONDOWN:
        drawing = True
        ix,iy = x,y
    elif event == cv2.EVENT_MOUSEMOVE:
        if drawing == True:
            cv2.rectangle(img,(ix,iy),(x,y),(0,255,233),-1)
    elif event == cv2.EVENT_LBUTTONUP:
        drawing = False
        cv2.rectangle(img,(ix,iy),(x,y),(0,255,233),-1)
# Showing the image 
img = np.zeros((512,512,3))

cv2.namedWindow(winname="draw")
cv2.setMouseCallback("draw",draw_rectangle)
 
while True:
    cv2.imshow('draw',img)
    if cv2.waitKey(1) & 0xFF == 27:
        break
cv2.destroyAllWindows()
